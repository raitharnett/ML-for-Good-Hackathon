# %% [markdown]
# <a href="https://colab.research.google.com/github/raitharnett/ML-for-Good-Hackathon/blob/main/cots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install --upgrade --force-reinstall --no-deps kaggle

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-7eee1ab9-89ad-4de8-a9e1-b8a13ad22bdf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7eee1ab9-89ad-4de8-a9e1-b8a13ad22bdf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 67 bytes

# %%
# %%bash
# mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# kaggle competitions download -c tensorflow-great-barrier-reef --force
# Out:
# ...
# 100%|██████████| 14.2G/14.2G [04:24<00:00, 57.6MB/s]
